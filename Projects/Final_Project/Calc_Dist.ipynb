# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.spatial import distance

# %%
class PlayIt():
    def __init__(self, dataset=None,user_choice=None,metric='euclidean',n_results=20):
        '''
        Initializing the class to calculate distance between games dataset        
        Parameters
        ----------
        dataset : pandas.DataFrame
            Dataset utilized in the analysis
        user_choice: dict
            Dictionary with the user choices 
        metric : str or function, optional
            The distance metric to use. The distance function can
            be 'braycurtis', 'canberra', 'chebyshev', 'cityblock',
            'correlation', 'cosine', 'dice', 'euclidean', 'hamming',
            'jaccard', 'jensenshannon', 'kulsinski', 'mahalanobis', 'matching',
            'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean',
            'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule'
            
        n_results : Number of similar games you want to see
        
        '''
        self.user_choice = user_choice
        self.dataset = dataset
        self.themes = ['Action', 'Adult','Adventure', 'Baseball', 'Battle', 'Board',
                      'Card','Casino', 'Compilation','Editor', 'Educational', 'Episodic', 'Fighting', 
                      'First-Person', 'Flight','Golf', 'Hardware', 'Hunting', 'Music', 'Other', 'Party', 
                      'Pet', 'Pinball', 'Platformer', 'Productivity', 'Puzzle', 'RPG', 'Racing', 'Shooter',
                      'Simulation','Sports', 'Strategy', 'Trivia', 'Virtual', 'Word', 'Wrestling']

        self.platforms = ['Sony', 'Microsoft','Nintendo','Portable', 'Old_Consoles', 'Mobile', 
                         'PC', 'Others_Plat','Playstation_4', 'Xbox_One','Wii_U']

        self.target_columns = ['old_game', 'critic_high_score'] + self.themes + self.platforms
        
        self.n_results = n_results
        
        self.metric = str(metric)
    
    def handle_result(self,result):
        
        result = result.iloc[-1]
        
        similar_games = result.sort_values()[1:].head(self.n_results)
        
        return self.dataset[['title','release_date','score','score_phrase','editors_choice','all_plat','genre','url']].iloc[similar_games.index]
        
    def calc_dist(self):
        
        calc_dist = pd.DataFrame(distance.squareform(distance.pdist(self.dataset.loc[:, self.target_columns], metric=self.metric)),
                              columns=self.dataset.index, 
                              index=self.dataset.title)
        return calc_dist
    
    def play_it(self):
        '''
        Function to calculate distance between user's input and the rest of the selected dataset
        '''
        new_line = pd.DataFrame.from_dict(self.user_choice)

        self.dataset = self.dataset.append(new_line,ignore_index=True)

        result = self.calc_dist()

        return self.handle_result(result)

# %%
user_choice = {'title':["User's choice"], 'release_date':[None],'score':[None],
               'score_phrase':[None],'editors_choice':[None],'genre':[None],
               'url':[None],'old_game':[0], 'critic_high_score':[0],'Sony':[0],
               'Microsoft':[0],'Nintendo':[1], 'Portable':[0],'Old_Consoles':[0],
               'Mobile':[0],'PC':[0],'Others_Plat':[0],'Playstation_4':[0],'Xbox_One':[0],
               'Wii_U':[0],'Action':[1],'Adult':[0],'Adventure':[0],'Baseball':[0],
               'Battle':[0],'Board':[0],'Card':[0],'Casino':[0],'Compilation':[0],'Editor':[0],
               'Educational':[0],'Episodic':[0],'Fighting':[1],'First-Person':[0],'Flight':[0],
               'Golf':[0],'Hardware':[0],'Hunting':[0],'Music':[0],'Other':[0],'Party':[0],
               'Pet':[0],'Pinball':[0],'Platformer':[0],'Productivity':[0],'Puzzle':[0],
               'RPG':[0],'Racing':[0],'Shooter':[0],'Simulation':[0],'Sports':[0],'Strategy':[0],
               'Trivia':[0],'Virtual':[0],'Word':[0],'Wrestling':[0]}

# %%
ign = pd.read_csv('dummy_ign.csv',sep='|')

play = PlayIt(ign,user_choice,metric='euclidean', n_results=20)

teste = play.play_it()

teste
# Out:
#                                               title release_date score  \
# 8459                                       Renegade   05/05/2008     6
# 11381                         Tournament of Legends   06/07/2010     5
# 1794             Castlevania: The Adventure ReBirth   07/01/2010     8
# 10469        Teenage Mutant Ninja Turtles: Smash-Up   22/09/2009     7
# 10463           Teenage Mutant Ninja Turtles [1989]   11/04/2007   5.5
# 1951                             ClayFighter [1994]   22/06/2009     4
# 6713                                   Muscle March   02/02/2010   6.1
# 1775                           Castlevania Judgment   18/11/2008   7.5
# 6717                   Mushroom Men: The Spore Wars   08/12/2008   7.9
# 2076                              Commando (Arcade)   14/01/2011     5
# 10258                              Super Turrican 2   29/09/2008   7.5
# 10247  Super Street Fighter II: The New Challengers   07/02/2008     8
# 6783                      Myth Makers: Orbs of Doom   27/02/2008   2.9
# 6785                 Myth Makers: Trixie in Toyland   03/09/2008   1.4
# 10622                               The Combatribes   30/11/2009     4
# 1969                                   Clu Clu Land   04/09/2008     5
# 10208               Super Monkey Ball: Banana Blitz   14/11/2006   8.4
# 10152                          Super Castlevania IV   11/01/2007     8
# 2520                               Deadly Creatures   06/02/2009     8
# 5023                           International Karate   25/02/2009     7
#
#       score_phrase editors_choice all_plat             genre  \
# 8459          Okay              N  ['Wii']  Fighting, Action
# 11381     Mediocre              N  ['Wii']  Fighting, Action
# 1794         Great              N  ['Wii']            Action
# 10469         Good              N  ['Wii']          Fighting
# 10463     Mediocre              N  ['Wii']            Action
# 1951           Bad              N  ['Wii']          Fighting
# 6713          Okay              N  ['Wii']            Action
# 1775          Good              N  ['Wii']          Fighting
# 6717          Good              N  ['Wii']            Action
# 2076      Mediocre              N  ['Wii']            Action
# 10258         Good              N  ['Wii']            Action
# 10247        Great              Y  ['Wii']          Fighting
# 6783       Painful              N  ['Wii']            Action
# 6785    Unbearable              N  ['Wii']            Action
# 10622          Bad              N  ['Wii']            Action
# 1969      Mediocre              N  ['Wii']            Action
# 10208        Great              Y  ['Wii']            Action
# 10152        Great              Y  ['Wii']            Action
# 2520         Great              Y  ['Wii']            Action
# 5023          Good              N  ['Wii']          Fighting
#
#                                                      url
# 8459     https://www.ign.com/games/renegade/wii-14247615
# 11381  https://www.ign.com/games/tournament-of-legend...
# 1794   https://www.ign.com/games/castlevania-the-adve...
# 10469  https://www.ign.com/games/teenage-mutant-ninja...
# 10463  https://www.ign.com/games/teenage-mutant-ninja...
# 1951   https://www.ign.com/games/clayfighter/wii-1424...
# 6713   https://www.ign.com/games/muscle-march/wii-143...
# 1775   https://www.ign.com/games/castlevania-judgment...
# 6717   https://www.ign.com/games/mushroom-men-rise-of...
# 2076   https://www.ign.com/games/capcom-arcade-hits-v...
# 10258  https://www.ign.com/games/super-turrican-2/wii...
# 10247  https://www.ign.com/games/super-street-fighter...
# 6783   https://www.ign.com/games/myth-makers-orbs-of-...
# 6785   https://www.ign.com/games/myth-makers-trixie-i...
# 10622    https://www.ign.com/games/combatribes/wii-37068
# 1969   https://www.ign.com/games/clu-clu-land/wii-142...
# 10208  https://www.ign.com/games/super-monkey-ball-ba...
# 10152  https://www.ign.com/games/super-castlevania-iv...
# 2520   https://www.ign.com/games/deadly-creatures-139...
# 5023           https://www.ign.com/games/ik/wii-14243627
