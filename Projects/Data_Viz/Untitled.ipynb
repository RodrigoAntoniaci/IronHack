# %%
import pandas as pd
import re

# %%
games = pd.read_csv('ign.csv',encoding='latin1')

# %% [markdown]
# games

# %%
games.drop(columns='Unnamed: 0',inplace=True)

# %%
games.sort_values(by='score',ascending=False)
# Out:
#       score_phrase                                    title  \
# 18624  Masterpiece                                   Inside
# 1434   Masterpiece                 Super Mario Bros. Deluxe
# 18432  Masterpiece     Metal Gear Solid V: The Phantom Pain
# 1592   Masterpiece              Mario Golf [Game Boy Color]
# 1363   Masterpiece                                 Shanghai
# ...            ...                                      ...
# 2334    Unbearable                 Kawasaki ATV Powersports
# 6440    Unbearable                      High Rollers Casino
# 12513     Disaster                      Action Girlz Racing
# 890       Disaster                       Extreme PaintBrawl
# 5242      Disaster  Looney Tunes: Back in Action: Zany Race
#
#                                                      url        platform  \
# 18624                 /games/inside-playdead/pc-20055740              PC
# 1434            /games/super-mario-bros-deluxe/gbc-11703  Game Boy Color
# ...

# %%
games.score = games.score.apply(lambda x: int(x * 10))

# %%
games.sort_values(by='score',ascending=True)
# Out:
#       score_phrase                                    title  \
# 5242      Disaster  Looney Tunes: Back in Action: Zany Race
# 890       Disaster                       Extreme PaintBrawl
# 12513     Disaster                      Action Girlz Racing
# 11362   Unbearable                    Backyard Baseball '09
# 1190    Unbearable                   Freestyle Boardin' '99
# ...            ...                                      ...
# 1434   Masterpiece                 Super Mario Bros. Deluxe
# 1408   Masterpiece                           Checkered Flag
# 1363   Masterpiece                                 Shanghai
# 8640   Masterpiece                            Tornado Mania
# 18624  Masterpiece                                   Inside
#
#                                                      url        platform  \
# 5242   /games/looney-tunes-back-in-action-zany-race/c...        Wireless
# 890                   /games/extreme-paintbrawl/pc-10455              PC
# ...

# %%
games.to_csv('ign_games.csv',sep='#',index=False)
